# %%
import zipfile
from datetime import datetime
from bs4 import BeautifulSoup
from prettytable import PrettyTable

def process_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    experiences = soup.find('section', {'id': 'experience-section'})

    if experiences:
        job_list = experiences.find_all('li', {'class': 'pv-profile-section__list-item'})
        job_table = PrettyTable(["Title", "Time Interval"])

        for job in job_list:
            title_tag = job.find('h3', {'class': 't-16'})
            title = title_tag.get_text().strip() if title_tag else ""
            
            if " at " in title.lower():
                title = title.split(" at ")[0].strip()
                
            date_range_element = job.find('h4', {'class': 'pv-entity__date-range'})
            if not date_range_element:
                continue

            time_interval = date_range_element.find_all('span')[1].get_text().strip()

            excluded_titles = ['intern', 'internship', 'student', 'contract', 'freelance', 'part-time']
            if any(excluded_title in title.lower() for excluded_title in excluded_titles):
                continue

            date_range = time_interval.split(' – ')
            start_date_str = date_range[0].strip()
            end_date_str = date_range[1].strip() if len(date_range) > 1 else ''

            try:
                start_date = datetime.strptime(start_date_str, '%b %Y')
            except ValueError:
                try:
                    start_date = datetime.strptime(start_date_str, '%Y')
                except ValueError:
                    continue

            try:
                end_date = datetime.strptime(end_date_str, '%b %Y') if end_date_str and end_date_str != 'Present' else datetime.now()
            except ValueError:
                try:
                    end_date = datetime.strptime(end_date_str, '%Y')
                except ValueError:
                    continue

            interval_str = f"{start_date.strftime('%Y.%m')} – {end_date.strftime('%Y.%m')}"
            job_table.add_row([title, interval_str])

        print(job_table)
        return True
    return False

with zipfile.ZipFile('linkedin_profiles.zip', 'r') as zip_file:
    successful_files = 0
    total_files = len([name for name in zip_file.namelist() if not (name.endswith("/") or name.startswith("__MACOSX"))])

    for file_name in zip_file.namelist():
        if file_name.endswith("/") or file_name.startswith("__MACOSX"):
            continue

        with zip_file.open(file_name, 'r') as html_file:
            html = html_file.read().decode('utf-8', errors='replace')
            print(f"Processing file {successful_files + 1} of {total_files}: {file_name}")
            print(f"Content preview: {html[:100]}\n")
            
            if process_html(html):
                successful_files += 1
            print(f"\nTotal successfully processed files so far: {successful_files}\n")
# Out:
# Processing file 1 of 447: linkedin_profiles/profile_jswong65.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-----------------------------+-------------------+
# |            Title            |   Time Interval   |
# +-----------------------------+-------------------+
# |      Software Engineer      | 2021.07 – 2023.03 |
# |    Software Engineer III    | 2019.01 – 2021.07 |
# | Graduate Teaching Assistant | 2013.08 – 2018.12 |
# |        Summer Analyst       | 2018.05 – 2018.08 |
# |      Research Associate     | 2015.06 – 2015.08 |
# +-----------------------------+-------------------+
#
# Total successfully processed files so far: 1
#
# Processing file 2 of 447: linkedin_profiles/profile_sunnychu.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +------------------------------+-------------------+
# |            Title             |   Time Interval   |
# +------------------------------+-------------------+
# |         Company Name         | 2016.08 – 2023.03 |
# |            Google            |                   |
# |   Finance Rotation Program   | 2010.08 – 2013.09 |
# | Education Research Assistant | 2009.08 – 2009.12 |
# |       Data Technician        | 2009.06 – 2009.12 |
# +------------------------------+-------------------+
#
# Total successfully processed files so far: 2
#
# Processing file 3 of 447: linkedin_profiles/profile_zexichen.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------------------+-------------------+
# |             Title             |   Time Interval   |
# +-------------------------------+-------------------+
# |       Software Engineer       | 2019.04 – 2023.03 |
# |       Software Engineer       | 2017.04 – 2019.04 |
# |          Company Name         | 2016.01 – 2017.04 |
# |     Meitu Technology (US)     |                   |
# | Software Development Engineer | 2015.05 – 2015.10 |
# |    Image Algorithm Engineer   | 2012.10 – 2013.07 |
# +-------------------------------+-------------------+
#
# Total successfully processed files so far: 3
#
# Processing file 4 of 447: linkedin_profiles/profile_jesse-furukawa.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------------------------+-------------------+
# |                   Title                    |   Time Interval   |
# +--------------------------------------------+-------------------+
# |             Software Engineer              | 2017.07 – 2023.03 |
# |          Data Analyst & Developer          | 2015.09 – 2016.12 |
# | Trading Tools Developer & Research Analyst | 2014.05 – 2014.09 |
# +--------------------------------------------+-------------------+
#
# Total successfully processed files so far: 4
#
# Processing file 5 of 447: linkedin_profiles/profile_chien-lin-chen-298890b1.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +------------------------------------------------+-------------------+
# |                     Title                      |   Time Interval   |
# +------------------------------------------------+-------------------+
# |               Software Engineer                | 2020.02 – 2023.03 |
# |                  Company Name                  | 2019.08 – 2020.01 |
# |                  IXL Learning                  |                   |
# |               Software Engineer                | 2016.06 – 2017.05 |
# | Product Manager in Product Planning Department | 2012.06 – 2014.06 |
# +------------------------------------------------+-------------------+
#
# Total successfully processed files so far: 5
#
# Processing file 6 of 447: linkedin_profiles/profile_abandimh01.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------------+-------------------+
# |           Title           |   Time Interval   |
# +---------------------------+-------------------+
# |     Software Engineer     | 2020.04 – 2023.03 |
# | Sr. Software Engineer, UI | 2019.09 – 2020.03 |
# |        Company Name       | 2017.12 – 2019.09 |
# |             HP            |                   |
# |        UI Developer       | 2015.12 – 2016.03 |
# |       Web Developer       | 2015.11 – 2015.12 |
# +---------------------------+-------------------+
#
# Total successfully processed files so far: 6
#
# Processing file 7 of 447: linkedin_profiles/profile_lwang88.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------------------+-------------------+
# |             Title             |   Time Interval   |
# +-------------------------------+-------------------+
# |       Software Engineer       | 2020.09 – 2023.03 |
# |       Software Engineer       | 2018.01 – 2020.09 |
# |       Production Manager      | 2012.09 – 2016.03 |
# | Electric Vehicle Battery Tech | 2009.05 – 2011.11 |
# +-------------------------------+-------------------+
#
# Total successfully processed files so far: 7
#
# Processing file 8 of 447: linkedin_profiles/profile_ranjith-kumar-n.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------+-------------------+
# |       Title        |   Time Interval   |
# +--------------------+-------------------+
# |    Company Name    | 2019.10 – 2023.03 |
# |       Intuit       |                   |
# |     Co-Founder     | 2016.10 – 2023.03 |
# |    Company Name    | 2017.03 – 2019.05 |
# |       Kohl's       |                   |
# | Software Developer | 2012.07 – 2014.08 |
# +--------------------+-------------------+
#
# Total successfully processed files so far: 8
#
# Processing file 9 of 447: linkedin_profiles/profile_tapanparikh.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-----------------------+-------------------+
# |         Title         |   Time Interval   |
# +-----------------------+-------------------+
# |   Software Engineer   | 2021.07 – 2023.03 |
# | Application Developer | 2017.02 – 2021.07 |
# |   Research Assistant  | 2015.10 – 2016.06 |
# |   Software Engineer   | 2013.06 – 2015.08 |
# +-----------------------+-------------------+
#
# Total successfully processed files so far: 9
#
# Processing file 10 of 447: linkedin_profiles/profile_maggiec22.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------+-------------------+
# |        Title        |   Time Interval   |
# +---------------------+-------------------+
# | Software Engineer I | 2021.06 – 2023.03 |
# |     Peer Advisor    | 2018.04 – 2021.06 |
# +---------------------+-------------------+
#
# Total successfully processed files so far: 10
#
# Processing file 11 of 447: linkedin_profiles/profile_arnaudhebert.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-----------------------------+-------------------+
# |            Title            |   Time Interval   |
# +-----------------------------+-------------------+
# |         Company Name        | 2020.10 – 2023.03 |
# |            Splunk           |                   |
# |         Company Name        | 2015.03 – 2015.04 |
# |            Ariba            |                   |
# | General-purpose team member | 2010.07 – 2010.09 |
# +-----------------------------+-------------------+
#
# Total successfully processed files so far: 11
#
# Processing file 12 of 447: linkedin_profiles/profile_roger-dunn11.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------+-------------------+
# |     Title     |   Time Interval   |
# +---------------+-------------------+
# |  Company Name | 2021.03 – 2023.03 |
# |     Tesla     |                   |
# |  Company Name | 2018.04 – 2019.04 |
# | JSR Micro Inc |                   |
# +---------------+-------------------+
#
# Total successfully processed files so far: 12
#
# Processing file 13 of 447: linkedin_profiles/profile_ramprasathvedavinayagam.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-----------------------------+-------------------+
# |            Title            |   Time Interval   |
# +-----------------------------+-------------------+
# |         Company Name        | 2021.05 – 2023.03 |
# |          BlackBerry         |                   |
# | Graduate Teaching Assistant | 2016.01 – 2016.06 |
# |      Software Engineer      | 2011.05 – 2014.06 |
# +-----------------------------+-------------------+
#
# Total successfully processed files so far: 13
#
# Processing file 14 of 447: linkedin_profiles/profile_swathym.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------+-------------------+
# |       Title        |   Time Interval   |
# +--------------------+-------------------+
# | Software Engineer  | 2020.01 – 2023.03 |
# | Software Developer | 2019.04 – 2020.01 |
# | Software Engineer  | 2016.03 – 2017.07 |
# | Software Engineer  | 2013.08 – 2016.03 |
# +--------------------+-------------------+
#
# Total successfully processed files so far: 14
#
# Processing file 15 of 447: linkedin_profiles/profile_neharahuja.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------------------+-------------------+
# |              Title              |   Time Interval   |
# +---------------------------------+-------------------+
# | Software Engineer III, Frontend | 2019.10 – 2023.03 |
# |         Senior Developer        | 2019.01 – 2019.10 |
# |           Company Name          | 2018.04 – 2019.01 |
# |        SAP SuccessFactors       |                   |
# +---------------------------------+-------------------+
#
# Total successfully processed files so far: 15
#
# Processing file 16 of 447: linkedin_profiles/profile_amit-dayal-28590284.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------+-------------------+
# |       Title        |   Time Interval   |
# +--------------------+-------------------+
# |    Company Name    | 2020.02 – 2023.03 |
# |       Tesla        |                   |
# | Software Developer | 2016.09 – 2017.05 |
# +--------------------+-------------------+
#
# Total successfully processed files so far: 16
#
# Processing file 17 of 447: linkedin_profiles/profile_abraham-william007.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------------+-------------------+
# |           Title           |   Time Interval   |
# +---------------------------+-------------------+
# |    Software Engineer 2    | 2021.09 – 2023.03 |
# |   Full Stack Engineer 2   | 2020.02 – 2021.09 |
# | Software Engineer -Target | 2013.01 – 2017.12 |
# +---------------------------+-------------------+
#
# Total successfully processed files so far: 17
#
# Processing file 18 of 447: linkedin_profiles/profile_suhankoh.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------+-------------------+
# |          Title           |   Time Interval   |
# +--------------------------+-------------------+
# | Senior Software Engineer | 2020.06 – 2023.03 |
# |    Software Engineer     | 2019.04 – 2020.05 |
# |       Company Name       | 2018.08 – 2019.04 |
# |   S&C Electric Company   |                   |
# +--------------------------+-------------------+
#
# Total successfully processed files so far: 18
#
# Processing file 19 of 447: linkedin_profiles/profile_apoorvmehta.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +------------------+-------------------+
# |      Title       |   Time Interval   |
# +------------------+-------------------+
# |   Company Name   | 2020.09 – 2023.03 |
# |    ServiceNow    |                   |
# | Systems Engineer | 2014.08 – 2016.08 |
# +------------------+-------------------+
#
# Total successfully processed files so far: 19
#
# Processing file 20 of 447: linkedin_profiles/profile_gauravkeswani.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +------------------------------------------+-------------------+
# |                  Title                   |   Time Interval   |
# +------------------------------------------+-------------------+
# |         Staff Software Engineer          | 2020.08 – 2023.03 |
# |               Company Name               | 2020.01 – 2020.08 |
# |                   Yelp                   |                   |
# |            Software Engineer             | 2016.06 – 2016.08 |
# | Graduate Teaching and Research Assistant | 2016.01 – 2016.05 |
# |            Software Engineer             | 2014.07 – 2015.07 |
# +------------------------------------------+-------------------+
#
# Total successfully processed files so far: 20
#
# Processing file 21 of 447: linkedin_profiles/profile_nikhil-sheth-06a872158.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +----------------------------------------------------------------------------------------+-------------------+
# |                                         Title                                          |   Time Interval   |
# +----------------------------------------------------------------------------------------+-------------------+
# |                                   Software Engineer                                    | 2021.01 – 2023.03 |
# | Multi Node Key-Value Store Distributed System with Replication and Partition Tolerance | 2019.09 – 2020.01 |
# |                                   Software Engineer                                    | 2019.06 – 2019.09 |
# |                                   Software Engineer                                    | 2018.06 – 2018.09 |
# |                              Software Engineer - Projects                              | 2013.01 – 2018.01 |
# +----------------------------------------------------------------------------------------+-------------------+
#
# Total successfully processed files so far: 21
#
# Processing file 22 of 447: linkedin_profiles/profile_vihangm.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +------------------------------+-------------------+
# |            Title             |   Time Interval   |
# +------------------------------+-------------------+
# |          Management          | 2020.02 – 2023.03 |
# | Full Stack Software Engineer | 2020.02 – 2023.03 |
# |  Software Engineer, Backend  | 2019.01 – 2020.02 |
# |     Full Stack Engineer      | 2018.07 – 2018.12 |
# |      Node.js Developer       | 2016.08 – 2018.06 |
# +------------------------------+-------------------+
#
# Total successfully processed files so far: 22
#
# Processing file 23 of 447: linkedin_profiles/profile_jainulpatel.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------+-------------------+
# |          Title           |   Time Interval   |
# +--------------------------+-------------------+
# |    Software Engineer     | 2019.07 – 2023.03 |
# |    Teaching Assistant    | 2017.09 – 2017.12 |
# | Senior Software Engineer | 2015.07 – 2017.07 |
# +--------------------------+-------------------+
#
# Total successfully processed files so far: 23
#
# Processing file 24 of 447: linkedin_profiles/profile_hmhouston7.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------------------+-------------------+
# |             Title             |   Time Interval   |
# +-------------------------------+-------------------+
# | Sr. Software Systems Engineer | 2020.12 – 2023.03 |
# |         Lacrosse Coach        | 2018.01 – 2020.04 |
# |       Software Engineer       | 2017.05 – 2020.04 |
# |      Software Consultant      | 2017.01 – 2017.05 |
# |        Backend Engineer       | 2015.12 – 2016.07 |
# +-------------------------------+-------------------+
#
# Total successfully processed files so far: 24
#
# Processing file 25 of 447: linkedin_profiles/profile_piyush-bageria.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------------------------+-------------------+
# |                 Title                 |   Time Interval   |
# +---------------------------------------+-------------------+
# |           Software Engineer           | 2019.08 – 2023.03 |
# |              UI Developer             | 2018.04 – 2019.08 |
# |              Company Name             | 2017.02 – 2018.04 |
# |                Globant                |                   |
# | Software Engineer,Product Development | 2014.02 – 2015.09 |
# |         Frontend Web Developer        | 2013.08 – 2014.01 |
# +---------------------------------------+-------------------+
#
# Total successfully processed files so far: 25
#
# Processing file 26 of 447: linkedin_profiles/profile_jessicaflorey.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------------------+-------------------+
# |                Title                 |   Time Interval   |
# +--------------------------------------+-------------------+
# |          Software Engineer           | 2017.06 – 2023.03 |
# |         Full Stack Developer         | 2015.02 – 2017.05 |
# | Business Analyst/Project Coordinator | 2013.02 – 2015.01 |
# +--------------------------------------+-------------------+
#
# Total successfully processed files so far: 26
#
# Processing file 27 of 447: linkedin_profiles/profile_rgbutov.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------+-------------------+
# |          Title           |   Time Interval   |
# +--------------------------+-------------------+
# | Senior Software Engineer | 2021.02 – 2023.03 |
# | Senior Software Engineer | 2018.06 – 2021.02 |
# |    Software Engineer     | 2018.05 – 2021.02 |
# |    Software Developer    | 2015.08 – 2018.04 |
# | Full-Stack Web Developer | 2013.02 – 2015.07 |
# +--------------------------+-------------------+
#
# Total successfully processed files so far: 27
#
# Processing file 28 of 447: linkedin_profiles/profile_vladimir-ponomarenko-00003622.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------------------+-------------------+
# |             Title             |   Time Interval   |
# +-------------------------------+-------------------+
# | Software Development Engineer | 2018.06 – 2023.03 |
# |       Software Engineer       | 2013.07 – 2018.05 |
# +-------------------------------+-------------------+
#
# Total successfully processed files so far: 28
#
# Processing file 29 of 447: linkedin_profiles/profile_yuehu1.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------+-------------------+
# |       Title       |   Time Interval   |
# +-------------------+-------------------+
# | Software Engineer | 2016.12 – 2023.03 |
# |    Company Name   | 2016.06 – 2016.12 |
# |      Zenefits     |                   |
# | Software Engineer | 2013.09 – 2015.09 |
# +-------------------+-------------------+
#
# Total successfully processed files so far: 29
#
# Processing file 30 of 447: linkedin_profiles/profile_harshasanjeev.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------+-------------------+
# |        Title        |   Time Interval   |
# +---------------------+-------------------+
# |  Software Engineer  | 2019.02 – 2023.03 |
# | Software Engineer 2 | 2018.10 – 2019.02 |
# |  Teaching Assistant | 2017.01 – 2018.05 |
# +---------------------+-------------------+
#
# Total successfully processed files so far: 30
#
# Processing file 31 of 447: linkedin_profiles/profile_manthanhdoshi.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------------------------------+-------------------+
# |                      Title                       |   Time Interval   |
# +--------------------------------------------------+-------------------+
# | Software Engineer - Systems Architecture (Cloud) | 2019.10 – 2023.03 |
# |                   Company Name                   | 2017.06 – 2019.10 |
# |                       eBay                       |                   |
# |           Vice President of Education            | 2018.01 – 2018.12 |
# |                   Company Name                   | 2017.03 – 2017.05 |
# |            San Jose State University             |                   |
# |                   Company Name                   | 2016.09 – 2016.12 |
# |            San Jose State University             |                   |
# +--------------------------------------------------+-------------------+
#
# Total successfully processed files so far: 31
#
# Processing file 32 of 447: linkedin_profiles/profile_avinashbhandari410.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------------+-------------------+
# |             Title              |   Time Interval   |
# +--------------------------------+-------------------+
# |          Company Name          | 2020.08 – 2023.03 |
# |             Tesla              |                   |
# |         RPA Developer          | 2018.05 – 2019.01 |
# |          Company Name          | 2018.01 – 2018.05 |
# | University of Central Missouri |                   |
# |          Company Name          | 2017.01 – 2017.07 |
# |           InfoBeans            |                   |
# |     Junior Java Developer      | 2014.01 – 2015.01 |
# +--------------------------------+-------------------+
#
# Total successfully processed files so far: 32
#
# Processing file 33 of 447: linkedin_profiles/profile_brandongiraldo.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------+-------------------+
# |       Title        |   Time Interval   |
# +--------------------+-------------------+
# | Software Engineer  | 2019.03 – 2023.03 |
# | Software Engineer  | 2017.07 – 2019.01 |
# |    Company Name    | 2014.08 – 2017.05 |
# | Cornell University |                   |
# +--------------------+-------------------+
#
# Total successfully processed files so far: 33
#
# Processing file 34 of 447: linkedin_profiles/profile_anujalakhote.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------+-------------------+
# |       Title        |   Time Interval   |
# +--------------------+-------------------+
# |    Company Name    | 2019.05 – 2023.03 |
# |       Tesla        |                   |
# | Software Developer | 2013.09 – 2014.06 |
# +--------------------+-------------------+
#
# Total successfully processed files so far: 34
#
# Processing file 35 of 447: linkedin_profiles/profile_chrispicato.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------------------+-------------------+
# |              Title              |   Time Interval   |
# +---------------------------------+-------------------+
# |        Software Engineer        | 2020.09 – 2023.03 |
# |     Senior Software Engineer    | 2018.06 – 2020.09 |
# |       Software Consultant       | 2017.03 – 2018.05 |
# |          CEO/Co-Founder         | 2015.01 – 2017.02 |
# | Senior Planner - Target Optical | 2015.03 – 2016.05 |
# +---------------------------------+-------------------+
#
# Total successfully processed files so far: 35
#
# Processing file 36 of 447: linkedin_profiles/profile_ambichetan.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------+-------------------+
# |          Title           |   Time Interval   |
# +--------------------------+-------------------+
# | Senior Software Engineer | 2019.10 – 2023.03 |
# |       Company Name       | 2017.05 – 2019.10 |
# |           eBay           |                   |
# |      Java Developer      | 2013.09 – 2014.05 |
# |    Software Engineer     | 2012.12 – 2013.05 |
# +--------------------------+-------------------+
#
# Total successfully processed files so far: 36
#
# Processing file 37 of 447: linkedin_profiles/profile_strom2357.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------+-------------------+
# |       Title       |   Time Interval   |
# +-------------------+-------------------+
# | Software Engineer | 2020.09 – 2023.03 |
# |    Company Name   | 2019.06 – 2020.09 |
# |       Cerego      |                   |
# +-------------------+-------------------+
#
# Total successfully processed files so far: 37
#
# Processing file 38 of 447: linkedin_profiles/profile_tiffanybalcarcel.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +------------------------------------------------------+-------------------+
# |                        Title                         |   Time Interval   |
# +------------------------------------------------------+-------------------+
# |                  Software Engineer                   | 2020.07 – 2023.03 |
# |                     Company Name                     | 2020.01 – 2020.05 |
# | Washington University McKelvey School of Engineering |                   |
# |        Director of Technological Development         | 2018.07 – 2019.11 |
# |              Technology Summer Analyst               | 2019.06 – 2019.08 |
# |                  Committee Director                  | 2016.12 – 2018.10 |
# +------------------------------------------------------+-------------------+
#
# Total successfully processed files so far: 38
#
# Processing file 39 of 447: linkedin_profiles/profile_amitratwani.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------+-------------------+
# |       Title       |   Time Interval   |
# +-------------------+-------------------+
# | Software Engineer | 2021.01 – 2023.03 |
# | Software Engineer | 2019.07 – 2020.12 |
# +-------------------+-------------------+
#
# Total successfully processed files so far: 39
#
# Processing file 40 of 447: linkedin_profiles/profile_jalbatross.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------------------------+-------------------+
# |                 Title                 |   Time Interval   |
# +---------------------------------------+-------------------+
# |     Software Development Engineer     | 2020.01 – 2023.03 |
# |          Full Stack Engineer          | 2018.12 – 2019.12 |
# | Data Analyst & Mathematics Instructor | 2017.09 – 2018.11 |
# |             Private Tutor             | 2014.01 – 2018.06 |
# |      Academic Tutor (Mathematics)     | 2017.01 – 2017.08 |
# +---------------------------------------+-------------------+
#
# Total successfully processed files so far: 40
#
# Processing file 41 of 447: linkedin_profiles/profile_fang-li-38085427.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------+-------------------+
# |          Title           |   Time Interval   |
# +--------------------------+-------------------+
# |    Software Engineer     | 2017.07 – 2023.03 |
# | Senior Software Engineer | 2015.07 – 2017.06 |
# | Senior Hardware Engineer | 2014.04 – 2015.07 |
# | Senior Hardware Engineer | 2011.06 – 2014.04 |
# +--------------------------+-------------------+
#
# Total successfully processed files so far: 41
#
# Processing file 42 of 447: linkedin_profiles/profile_sheetalparanjpe.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------+-------------------+
# |          Title           |   Time Interval   |
# +--------------------------+-------------------+
# |       Company Name       | 2021.09 – 2023.03 |
# |         LinkedIn         |                   |
# |    Software Engineer     | 2016.03 – 2017.10 |
# |    Software Engineer     | 2015.03 – 2016.03 |
# | Senior Software Engineer | 2010.03 – 2012.12 |
# +--------------------------+-------------------+
#
# Total successfully processed files so far: 42
#
# Processing file 43 of 447: linkedin_profiles/profile_talal916.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------------+-------------------+
# |          Title          |   Time Interval   |
# +-------------------------+-------------------+
# |    Software Engineer    | 2020.07 – 2023.03 |
# |    Software Engineer    | 2020.01 – 2020.06 |
# |       Company Name      | 2019.08 – 2020.01 |
# |    Redtail Technology   |                   |
# |       Company Name      | 2019.05 – 2020.01 |
# |     Hornet Hyperloop    |                   |
# | Instructional Assistant | 2015.08 – 2019.07 |
# +-------------------------+-------------------+
#
# Total successfully processed files so far: 43
#
# Processing file 44 of 447: linkedin_profiles/profile_billywon.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +------------------------------+-------------------+
# |            Title             |   Time Interval   |
# +------------------------------+-------------------+
# |      Software Engineer       | 2021.09 – 2023.03 |
# |      Software Engineer       | 2018.01 – 2021.07 |
# | Software Engineering Fellow  | 2017.04 – 2017.08 |
# | Investor Relations Associate | 2013.12 – 2016.04 |
# |       System Engineer        | 2012.07 – 2013.08 |
# +------------------------------+-------------------+
#
# Total successfully processed files so far: 44
#
# Processing file 45 of 447: linkedin_profiles/profile_siddiq235.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +----------------------------------+-------------------+
# |              Title               |   Time Interval   |
# +----------------------------------+-------------------+
# |       Software Engineer II       | 2021.10 – 2023.03 |
# |        Software Engineer         | 2017.02 – 2021.10 |
# |        Software Engineer         | 2016.09 – 2017.01 |
# | Full Stack Engineer (Consultant) | 2016.07 – 2016.08 |
# |           Company Name           | 2015.08 – 2015.12 |
# |    San Jose State University     |                   |
# +----------------------------------+-------------------+
#
# Total successfully processed files so far: 45
#
# Processing file 46 of 447: linkedin_profiles/profile_yu-jian-bayarea.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------+-------------------+
# |       Title       |   Time Interval   |
# +-------------------+-------------------+
# | Software Engineer | 2019.08 – 2023.03 |
# | Software Engineer | 2016.08 – 2019.08 |
# | Software Engineer | 2015.04 – 2016.07 |
# | Software Engineer | 2014.01 – 2015.04 |
# +-------------------+-------------------+
#
# Total successfully processed files so far: 46
#
# Processing file 47 of 447: linkedin_profiles/profile_kevin-chou-29487312.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------------------------+-------------------+
# |                 Title                 |   Time Interval   |
# +---------------------------------------+-------------------+
# |           Software Engineer           | 2021.09 – 2023.03 |
# |           Software Engineer           | 2020.02 – 2021.09 |
# |          Actuarial Developer          | 2018.11 – 2019.05 |
# |          Actuarial Developer          | 2016.11 – 2018.11 |
# | English Teacher and College Counselor | 2014.05 – 2015.11 |
# +---------------------------------------+-------------------+
#
# Total successfully processed files so far: 47
#
# Processing file 48 of 447: linkedin_profiles/profile_kshruthi269.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------+-------------------+
# |        Title        |   Time Interval   |
# +---------------------+-------------------+
# |     Company Name    | 2018.10 – 2023.03 |
# |         IBM         |                   |
# | Technical Associate | 2011.01 – 2013.04 |
# +---------------------+-------------------+
#
# Total successfully processed files so far: 48
#
# Processing file 49 of 447: linkedin_profiles/profile_valeryn.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------+-------------------+
# |       Title       |   Time Interval   |
# +-------------------+-------------------+
# | Software Engineer | 2021.05 – 2023.03 |
# | Software Engineer | 2019.09 – 2021.05 |
# | Software Engineer | 2018.01 – 2019.01 |
# |    Company Name   | 2011.10 – 2018.01 |
# |       Areva       |                   |
# +-------------------+-------------------+
#
# Total successfully processed files so far: 49
#
# Processing file 50 of 447: linkedin_profiles/profile_digantjain.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------+-------------------+
# |       Title        |   Time Interval   |
# +--------------------+-------------------+
# | Software Engineer  | 2020.02 – 2023.03 |
# | Teaching Assistant | 2019.01 – 2020.02 |
# | Software Engineer  | 2015.07 – 2018.06 |
# +--------------------+-------------------+
#
# Total successfully processed files so far: 50
#
# Processing file 51 of 447: linkedin_profiles/profile_jayadev-akkiraju-b947576a.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +------------------------------------------+-------------------+
# |                  Title                   |   Time Interval   |
# +------------------------------------------+-------------------+
# |            Software Engineer             | 2019.11 – 2023.03 |
# |         Senior Software Engineer         | 2019.04 – 2019.11 |
# |            Software Engineer             | 2017.03 – 2019.04 |
# |            Frontend Engineer             | 2015.08 – 2017.03 |
# | Frontend Engineer - Cisco Cloud Services | 2015.03 – 2015.08 |
# +------------------------------------------+-------------------+
#
# Total successfully processed files so far: 51
#
# Processing file 52 of 447: linkedin_profiles/profile_hndfaw.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-----------------------------------+-------------------+
# |               Title               |   Time Interval   |
# +-----------------------------------+-------------------+
# | Software Engineer (REACH Program) | 2021.07 – 2023.03 |
# |         Software Developer        | 2020.11 – 2021.06 |
# | Monitoring and Evaluation Manager | 2018.02 – 2018.10 |
# |            Company Name           | 2017.03 – 2017.12 |
# |         Global Communities        |                   |
# +-----------------------------------+-------------------+
#
# Total successfully processed files so far: 52
#
# Processing file 53 of 447: linkedin_profiles/profile_chengwei-hsieh-15772b108.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------+-------------------+
# |          Title           |   Time Interval   |
# +--------------------------+-------------------+
# | Senior Software Engineer | 2020.01 – 2023.03 |
# |    Firmware Engineer     | 2018.08 – 2020.01 |
# |       Company Name       | 2014.12 – 2018.08 |
# |         Qualcomm         |                   |
# +--------------------------+-------------------+
#
# Total successfully processed files so far: 53
#
# Processing file 54 of 447: linkedin_profiles/profile_om-chidananda.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------+-------------------+
# |       Title       |   Time Interval   |
# +-------------------+-------------------+
# | Software Engineer | 2015.03 – 2023.03 |
# | Software Engineer | 2014.10 – 2015.03 |
# +-------------------+-------------------+
#
# Total successfully processed files so far: 54
#
# Processing file 55 of 447: linkedin_profiles/profile_ouning-zhang-39972324.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------+-------------------+
# |       Title       |   Time Interval   |
# +-------------------+-------------------+
# |    Company Name   | 2020.07 – 2023.03 |
# |       Amazon      |                   |
# | Software Engineer | 2013.10 – 2017.01 |
# | Software Engineer | 2012.07 – 2013.10 |
# +-------------------+-------------------+
#
# Total successfully processed files so far: 55
#
# Processing file 56 of 447: linkedin_profiles/profile_nada-al-thawr.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------------------+-------------------+
# |              Title              |   Time Interval   |
# +---------------------------------+-------------------+
# |        Software Engineer        | 2021.04 – 2023.03 |
# |       Software Consultant       | 2019.07 – 2021.03 |
# | Business Intelligence Associate | 2018.09 – 2019.05 |
# |           Company Name          | 2018.09 – 2019.05 |
# |      Mount Holyoke College      |                   |
# +---------------------------------+-------------------+
#
# Total successfully processed files so far: 56
#
# Processing file 57 of 447: linkedin_profiles/profile_nickolas-westman-09886842.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------+-------------------+
# |          Title           |   Time Interval   |
# +--------------------------+-------------------+
# | Senior Software Engineer | 2020.02 – 2023.03 |
# |          Owner           | 2021.08 – 2023.03 |
# |    Software Engineer     | 2016.05 – 2020.02 |
# |   Software Engineer II   | 2015.02 – 2016.04 |
# +--------------------------+-------------------+
#
# Total successfully processed files so far: 57
#
# Processing file 58 of 447: linkedin_profiles/profile_hchenmo.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------+-------------------+
# |       Title        |   Time Interval   |
# +--------------------+-------------------+
# | Software Engineer  | 2019.10 – 2023.03 |
# | Frontend Engineer  | 2017.09 – 2019.10 |
# |    Company Name    | 2013.11 – 2016.12 |
# | Dolby Laboratories |                   |
# +--------------------+-------------------+
#
# Total successfully processed files so far: 58
#
# Processing file 59 of 447: linkedin_profiles/profile_joeyfeng.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +----------------------------+-------------------+
# |           Title            |   Time Interval   |
# +----------------------------+-------------------+
# |     Software Engineer      | 2018.11 – 2023.03 |
# |  Ruby on Rails Consultant  | 2018.08 – 2018.10 |
# | Associate Campaign Manager | 2016.11 – 2017.11 |
# |     Affiliate Manager      | 2014.02 – 2016.07 |
# |        Data Analyst        | 2012.01 – 2013.11 |
# +----------------------------+-------------------+
#
# Total successfully processed files so far: 59
#
# Processing file 60 of 447: linkedin_profiles/profile_gary-watson-2b37741a5.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------+-------------------+
# |          Title           |   Time Interval   |
# +--------------------------+-------------------+
# | Senior Software Engineer | 2019.11 – 2023.03 |
# |     Python Developer     | 2018.01 – 2019.10 |
# |    Software Engineer     | 2013.07 – 2017.12 |
# +--------------------------+-------------------+
#
# Total successfully processed files so far: 60
#
# Processing file 61 of 447: linkedin_profiles/profile_chsrinivasan.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-----------------------------+-------------------+
# |            Title            |   Time Interval   |
# +-----------------------------+-------------------+
# |         Company Name        | 2018.10 – 2023.03 |
# |            Oracle           |                   |
# | Business Technology Analyst | 2013.08 – 2015.07 |
# +-----------------------------+-------------------+
#
# Total successfully processed files so far: 61
#
# Processing file 62 of 447: linkedin_profiles/profile_bimalbpaul.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------+-------------------+
# |          Title           |   Time Interval   |
# +--------------------------+-------------------+
# |       Company Name       | 2020.06 – 2023.03 |
# |         Autodesk         |                   |
# |       Company Name       | 2017.12 – 2019.03 |
# |         Corteva          |                   |
# | Consultant UI Developer  | 2016.03 – 2016.06 |
# |   Development Analyst    | 2015.09 – 2016.03 |
# | Senior Software Engineer | 2013.12 – 2015.05 |
# +--------------------------+-------------------+
#
# Total successfully processed files so far: 62
#
# Processing file 63 of 447: linkedin_profiles/profile_braden-altstatt.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------+-------------------+
# |       Title       |   Time Interval   |
# +-------------------+-------------------+
# | Software Engineer | 2021.03 – 2023.03 |
# | Software Engineer | 2019.08 – 2021.03 |
# | Software Engineer | 2019.01 – 2020.01 |
# | Software Engineer | 2018.01 – 2023.03 |
# |     Co-Founder    | 2016.01 – 2018.01 |
# +-------------------+-------------------+
#
# Total successfully processed files so far: 63
#
# Processing file 64 of 447: linkedin_profiles/profile_sruti-paku-98694822.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +------------------------------------+-------------------+
# |               Title                |   Time Interval   |
# +------------------------------------+-------------------+
# |         Software Engineer          | 2020.05 – 2023.03 |
# | Associate Senior Software Engineer | 2017.08 – 2020.04 |
# |   Software Development Engineer    | 2013.09 – 2015.07 |
# +------------------------------------+-------------------+
#
# Total successfully processed files so far: 64
#
# Processing file 65 of 447: linkedin_profiles/profile_anatolii-kurochkin.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------+-------------------+
# |          Title           |   Time Interval   |
# +--------------------------+-------------------+
# | Senior Software Engineer | 2021.09 – 2023.03 |
# |       Company Name       | 2020.02 – 2021.09 |
# |       CallFromWeb        |                   |
# | Senior Software Engineer | 2019.06 – 2021.05 |
# |          Judge           | 2019.10 – 2023.03 |
# | Senior Software Engineer | 2018.10 – 2019.07 |
# +--------------------------+-------------------+
#
# Total successfully processed files so far: 65
#
# Processing file 66 of 447: linkedin_profiles/profile_the-real-sherman-chen.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------------------+-------------------+
# |              Title              |   Time Interval   |
# +---------------------------------+-------------------+
# |     Senior Software Engineer    | 2019.05 – 2023.03 |
# |        Software Engineer        | 2017.06 – 2019.05 |
# | General Manager / Web Developer | 2014.10 – 2015.09 |
# +---------------------------------+-------------------+
#
# Total successfully processed files so far: 66
#
# Processing file 67 of 447: linkedin_profiles/profile_naveesh.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------+-------------------+
# |       Title        |   Time Interval   |
# +--------------------+-------------------+
# |    Company Name    | 2020.04 – 2023.03 |
# |       Amazon       |                   |
# |    Company Name    | 2016.01 – 2016.08 |
# | Cerner Corporation |                   |
# +--------------------+-------------------+
#
# Total successfully processed files so far: 67
#
# Processing file 68 of 447: linkedin_profiles/profile_baggasumit.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +----------------------+-------------------+
# |        Title         |   Time Interval   |
# +----------------------+-------------------+
# |  Software Engineer   | 2019.07 – 2023.03 |
# | Software QA Engineer | 2015.01 – 2019.07 |
# +----------------------+-------------------+
#
# Total successfully processed files so far: 68
#
# Processing file 69 of 447: linkedin_profiles/profile_ktmud.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-----------------------------------+-------------------+
# |               Title               |   Time Interval   |
# +-----------------------------------+-------------------+
# | Software Engineer, Infrastructure | 2020.01 – 2023.03 |
# |         Data Scientist II         | 2019.03 – 2020.01 |
# |    Graduate Research Assistant    | 2017.01 – 2018.12 |
# |    Quantitative Developer Co-op   | 2018.01 – 2018.04 |
# +-----------------------------------+-------------------+
#
# Total successfully processed files so far: 69
#
# Processing file 70 of 447: linkedin_profiles/profile_jeffreyyoung4.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------+-------------------+
# |       Title       |   Time Interval   |
# +-------------------+-------------------+
# | Software Engineer | 2020.01 – 2023.03 |
# |   Lead Developer  | 2019.01 – 2019.03 |
# | Software Engineer | 2016.08 – 2019.01 |
# +-------------------+-------------------+
#
# Total successfully processed files so far: 70
#
# Processing file 71 of 447: linkedin_profiles/profile_karen-peng-4a433162.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------+-------------------+
# |          Title           |   Time Interval   |
# +--------------------------+-------------------+
# | Senior Software Engineer | 2016.03 – 2023.03 |
# |    Software Engineer     | 2015.10 – 2016.03 |
# | Open Source Contributor  | 2015.05 – 2015.12 |
# +--------------------------+-------------------+
#
# Total successfully processed files so far: 71
#
# Processing file 72 of 447: linkedin_profiles/profile_ryanmchow.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
# ...
# +-------------------+-------------------+
# |    Company Name   | 2021.02 – 2023.03 |
# |       Airbnb      |                   |
# | Software Engineer | 2016.12 – 2019.02 |
# |    GIS Analyst    | 2015.01 – 2016.06 |
# +-------------------+-------------------+
#
# Total successfully processed files so far: 424
#
# Processing file 425 of 447: linkedin_profiles/profile_arunmanickam.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------------------+-------------------+
# |              Title              |   Time Interval   |
# +---------------------------------+-------------------+
# |           Company Name          | 2020.10 – 2023.03 |
# |              Google             |                   |
# |           Company Name          | 2018.08 – 2019.06 |
# |              PayPal             |                   |
# | Business Intelligence Developer | 2017.11 – 2018.08 |
# | Software Development Engineer 2 | 2015.06 – 2017.07 |
# |        Research Assistant       | 2013.07 – 2014.08 |
# +---------------------------------+-------------------+
#
# Total successfully processed files so far: 425
#
# Processing file 426 of 447: linkedin_profiles/profile_ctong5.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------+-------------------+
# |       Title       |   Time Interval   |
# +-------------------+-------------------+
# | Software Engineer | 2021.10 – 2023.03 |
# | Software Engineer | 2019.11 – 2021.10 |
# |    Company Name   | 2019.01 – 2019.11 |
# | Personal Projects |                   |
# |    Company Name   | 2015.04 – 2019.03 |
# |      Red Bull     |                   |
# +-------------------+-------------------+
#
# Total successfully processed files so far: 426
#
# Processing file 427 of 447: linkedin_profiles/profile_leilisv.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------+-------------------+
# |       Title        |   Time Interval   |
# +--------------------+-------------------+
# | Software Engineer  | 2021.04 – 2023.03 |
# | Software Engineer  | 2018.07 – 2021.04 |
# | front end engineer | 2015.09 – 2017.12 |
# | front end engineer | 2015.04 – 2015.06 |
# | front end engineer | 2014.09 – 2015.04 |
# +--------------------+-------------------+
#
# Total successfully processed files so far: 427
#
# Processing file 428 of 447: linkedin_profiles/profile_gavinblee.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------+-------------------+
# |       Title       |   Time Interval   |
# +-------------------+-------------------+
# | Software Engineer | 2021.02 – 2023.03 |
# | Software Engineer | 2018.01 – 2021.02 |
# |   Private Tutor   | 2016.05 – 2017.12 |
# |     Webmaster     | 2015.11 – 2017.12 |
# +-------------------+-------------------+
#
# Total successfully processed files so far: 428
#
# Processing file 429 of 447: linkedin_profiles/profile_jian-shen-cs.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------------------+-------------------+
# |             Title             |   Time Interval   |
# +-------------------------------+-------------------+
# |    Senior Software Engineer   | 2020.08 – 2023.03 |
# |          Company Name         | 2018.03 – 2020.06 |
# |              Uber             |                   |
# | Software Development Engineer | 2014.07 – 2015.12 |
# +-------------------------------+-------------------+
#
# Total successfully processed files so far: 429
#
# Processing file 430 of 447: linkedin_profiles/profile_kavitshah8.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------------------+-------------------+
# |              Title              |   Time Interval   |
# +---------------------------------+-------------------+
# | Software Development Engineer 4 | 2017.04 – 2023.03 |
# |           Company Name          | 2016.05 – 2017.03 |
# |              Citrix             |                   |
# |  Instructor of Programming in C | 2014.08 – 2014.12 |
# +---------------------------------+-------------------+
#
# Total successfully processed files so far: 430
#
# Processing file 431 of 447: linkedin_profiles/profile_burhanwani.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +----------------------+-------------------+
# |        Title         |   Time Interval   |
# +----------------------+-------------------+
# | Software Engineer II | 2021.06 – 2023.03 |
# |     Company Name     | 2018.11 – 2021.06 |
# |        Cisco         |                   |
# +----------------------+-------------------+
#
# Total successfully processed files so far: 431
#
# Processing file 432 of 447: linkedin_profiles/profile_arjun-garg-5b331923.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------+-------------------+
# |          Title           |   Time Interval   |
# +--------------------------+-------------------+
# | Senior Software Engineer | 2019.06 – 2023.03 |
# | Senior Software Engineer | 2017.11 – 2019.06 |
# |  Technology Specialist   | 2016.02 – 2017.11 |
# |     Development Lead     | 2015.02 – 2016.02 |
# |       Company Name       | 2013.08 – 2015.01 |
# |         Infosys          |                   |
# +--------------------------+-------------------+
#
# Total successfully processed files so far: 432
#
# Processing file 433 of 447: linkedin_profiles/profile_mihirmathur1.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-------------------+-------------------+
# |       Title       |   Time Interval   |
# +-------------------+-------------------+
# | Software Engineer | 2020.08 – 2023.03 |
# |     President     | 2016.04 – 2018.04 |
# +-------------------+-------------------+
#
# Total successfully processed files so far: 433
#
# Processing file 434 of 447: linkedin_profiles/profile_stephcfong.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-----------------------------------+-------------------+
# |               Title               |   Time Interval   |
# +-----------------------------------+-------------------+
# |            Company Name           | 2021.05 – 2023.03 |
# |             Salesforce            |                   |
# |             Recruiter             | 2017.09 – 2019.04 |
# | Technical Recruiter - Engineering | 2016.07 – 2017.08 |
# +-----------------------------------+-------------------+
#
# Total successfully processed files so far: 434
#
# Processing file 435 of 447: linkedin_profiles/profile_amadousallah.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------------+-------------------+
# |           Title           |   Time Interval   |
# +---------------------------+-------------------+
# |     Software Engineer     | 2019.09 – 2023.03 |
# |      Technical Mentor     | 2017.01 – 2019.08 |
# |     Software Engineer     | 2015.01 – 2016.01 |
# | Software Engineer, Mentor | 2014.01 – 2015.01 |
# | Component Design Engineer | 2011.01 – 2014.01 |
# +---------------------------+-------------------+
#
# Total successfully processed files so far: 435
#
# Processing file 436 of 447: linkedin_profiles/profile_anudeep-chennupati-50a1b939.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------------------------------------------+-------------------+
# |                            Title                             |   Time Interval   |
# +--------------------------------------------------------------+-------------------+
# |                      Software Engineer                       | 2019.08 – 2023.03 |
# |                             MTS                              | 2016.02 – 2019.08 |
# |                Member of the Technical Staff                 | 2016.02 – 2019.08 |
# | Graduate Teaching Assistant - Data Structures and Algorithms | 2015.09 – 2015.12 |
# +--------------------------------------------------------------+-------------------+
#
# Total successfully processed files so far: 436
#
# Processing file 437 of 447: linkedin_profiles/profile_gofronmichael.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +------------------------------------------+-------------------+
# |                  Title                   |   Time Interval   |
# +------------------------------------------+-------------------+
# |            Software Engineer             | 2016.12 – 2023.03 |
# |    Software Engineer and Tech Mentor     | 2016.06 – 2016.09 |
# | Teaching Assistant for Computer Graphics | 2016.01 – 2016.04 |
# +------------------------------------------+-------------------+
#
# Total successfully processed files so far: 437
#
# Processing file 438 of 447: linkedin_profiles/profile_pauldufour.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------+-------------------+
# |          Title           |   Time Interval   |
# +--------------------------+-------------------+
# | Senior Software Engineer | 2020.03 – 2023.03 |
# | Senior Software Engineer | 2019.10 – 2020.03 |
# | Senior Software Engineer | 2012.02 – 2019.05 |
# |        Programmer        | 2009.01 – 2010.01 |
# +--------------------------+-------------------+
#
# Total successfully processed files so far: 438
#
# Processing file 439 of 447: linkedin_profiles/profile_dhwei.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------------------+-------------------+
# |                Title                 |   Time Interval   |
# +--------------------------------------+-------------------+
# |    Software Development Engineer     | 2021.08 – 2023.03 |
# | Complex Securities Valuation Analyst | 2017.08 – 2021.07 |
# |      Investment Banking Auditor      | 2015.10 – 2016.02 |
# +--------------------------------------+-------------------+
#
# Total successfully processed files so far: 439
#
# Processing file 440 of 447: linkedin_profiles/profile_patelumesh.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------------------+-------------------+
# |                Title                 |   Time Interval   |
# +--------------------------------------+-------------------+
# |      Senior Software Engineer 3      | 2019.07 – 2023.03 |
# | Senior Software Development Engineer | 2017.11 – 2019.05 |
# |       Senior Software Engineer       | 2016.09 – 2017.11 |
# |            Technical Lead            | 2015.05 – 2016.09 |
# |          Production Support          | 2014.11 – 2015.07 |
# +--------------------------------------+-------------------+
#
# Total successfully processed files so far: 440
#
# Processing file 441 of 447: linkedin_profiles/profile_ameya-nawale.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +---------------------------+-------------------+
# |           Title           |   Time Interval   |
# +---------------------------+-------------------+
# |  Senior Software Engineer | 2021.01 – 2023.03 |
# | Member Of Technical Staff | 2019.07 – 2021.01 |
# |   Associate - Technology  | 2014.02 – 2017.07 |
# +---------------------------+-------------------+
#
# Total successfully processed files so far: 441
#
# Processing file 442 of 447: linkedin_profiles/profile_nthnleo.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-----------------------------+-------------------+
# |            Title            |   Time Interval   |
# +-----------------------------+-------------------+
# |         Company Name        | 2021.08 – 2023.03 |
# |            Adobe            |                   |
# |         Company Name        | 2018.04 – 2019.04 |
# |  Marketo, an Adobe Company  |                   |
# | Hardware Support Consultant | 2014.06 – 2016.01 |
# +-----------------------------+-------------------+
#
# Total successfully processed files so far: 442
#
# Processing file 443 of 447: linkedin_profiles/profile_alejandrogarciasalas.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +------------------------------------+-------------------+
# |               Title                |   Time Interval   |
# +------------------------------------+-------------------+
# |         Software Engineer          | 2019.06 – 2023.03 |
# |           Accel Scholar            | 2017.09 – 2018.05 |
# |            Company Name            | 2016.02 – 2018.02 |
# | University of California, Berkeley |                   |
# +------------------------------------+-------------------+
#
# Total successfully processed files so far: 443
#
# Processing file 444 of 447: linkedin_profiles/profile_wei-wang-ph-d-011850a.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +------------------------------------------+-------------------+
# |                  Title                   |   Time Interval   |
# +------------------------------------------+-------------------+
# |             Color Scientist              | 2020.01 – 2023.03 |
# | Senior Color and Image Quality Scientist | 2017.01 – 2020.01 |
# |             Vision Scientist             | 2016.01 – 2023.03 |
# |         Color Imaging Scientist          | 2013.01 – 2023.03 |
# +------------------------------------------+-------------------+
#
# Total successfully processed files so far: 444
#
# Processing file 445 of 447: linkedin_profiles/profile_tijesunimi-peters.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-----------------------------------------------+-------------------+
# |                     Title                     |   Time Interval   |
# +-----------------------------------------------+-------------------+
# |       Java Software Engineer - Braintree      | 2020.10 – 2023.03 |
# |          Team Lead Software Engineer          | 2019.01 – 2020.01 |
# |               Software Developer              | 2016.05 – 2020.01 |
# |               Frontend Developer              | 2017.05 – 2018.11 |
# | Javascript Developer and Software QA Engineer | 2017.01 – 2018.08 |
# +-----------------------------------------------+-------------------+
#
# Total successfully processed files so far: 445
#
# Processing file 446 of 447: linkedin_profiles/profile_vineethm99.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +--------------------------+-------------------+
# |          Title           |   Time Interval   |
# +--------------------------+-------------------+
# | Senior Software Engineer | 2016.06 – 2023.03 |
# +--------------------------+-------------------+
#
# Total successfully processed files so far: 446
#
# Processing file 447 of 447: linkedin_profiles/profile_rileybrenner.htm
# Content preview: <html lang="en" class="theme theme--mercado artdeco windows"><head>
#     <script type="application/j
#
# +-----------------------------+-------------------+
# |            Title            |   Time Interval   |
# +-----------------------------+-------------------+
# |         Company Name        | 2021.10 – 2023.03 |
# |            Adobe            |                   |
# | Marketing and Sales Manager | 2014.08 – 2015.06 |
# |       Account Manager       | 2015.02 – 2015.05 |
# +-----------------------------+-------------------+
#
# Total successfully processed files so far: 447
